# %% [markdown]
# ## 1.特定する都道府県の物件のみを抽出する

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os

# データの読み込み
data_path = '/Users/hayakawakazue/Downloads/second_apt_2024_summer/test/test_01/test.csv'
test_data = pd.read_csv(data_path, low_memory=False)

# 都道府県名のユニークな値を確認
print(test_data['都道府県名'].unique())

# 選択した都道府県の物件のみを抽出
target_prefectures = ['東京都', '大阪府']
concat_test_data = test_data[test_data['都道府県名'].isin(target_prefectures)]

# データの確認
print(concat_test_data.head())

# ディレクトリが存在するか確認し、存在しない場合は作成
save_dir = '/Users/hayakawakazue/Downloads/second_apt_2024_summer/test/test_13_27'
if not os.path.exists(save_dir):
    os.makedirs(save_dir)

# データを保存
concat_test_data_path = os.path.join(save_dir, 'test_13_27.csv')
concat_test_data.to_csv(concat_test_data_path, index=False)

print(f"データを保存しました: {concat_test_data_path}")

# データセットに含まれる行の数を確認
num_rows = concat_test_data.shape[0]
print(f"データセットに含まれる行の数: {num_rows}")
# Out:
# ['北海道' '青森県' '岩手県' '宮城県' '秋田県' '山形県' '福島県' '茨城県' '栃木県' '群馬県' '埼玉県' '千葉県'
#  '東京都' '神奈川県' '新潟県' '富山県' '石川県' '福井県' '山梨県' '長野県' '岐阜県' '静岡県' '愛知県' '三重県'
#  '滋賀県' '京都府' '大阪府' '兵庫県' '奈良県' '和歌山県' '鳥取県' '島根県' '岡山県' '広島県' '山口県' '徳島県'
#  '香川県' '愛媛県' '高知県' '福岡県' '佐賀県' '長崎県' '熊本県' '大分県' '宮崎県' '鹿児島県' '沖縄県']
#             ID        種類  価格情報区分  地域  市区町村コード 都道府県名 市区町村名  地区名  最寄駅：名称  \
# 9316  13000559  中古マンション等  成約価格情報 NaN    13101   東京都  千代田区  岩本町     岩本町
# 9317  13000560  中古マンション等  成約価格情報 NaN    13101   東京都  千代田区  岩本町     岩本町
# 9318  13000561  中古マンション等  成約価格情報 NaN    13101   東京都  千代田区  岩本町     岩本町
# 9319  13000562  中古マンション等  成約価格情報 NaN    13101   東京都  千代田区  岩本町     秋葉原
# 9320  13000563  中古マンション等  成約価格情報 NaN    13101   東京都  千代田区  岩本町  神田(東京)
#
#      最寄駅：距離（分）  ... 今後の利用目的  前面道路：方位  前面道路：種類  前面道路：幅員（ｍ）  都市計画 建ぺい率（％）  \
# 9316         4  ...     NaN      NaN      NaN         NaN    商業     NaN
# 9317         3  ...     NaN      NaN      NaN         NaN    商業     NaN
# ...

# %% [markdown]
# ## テストデータセットの東京都多摩を選択する　（必要な場合）

# %%
import pandas as pd

# データの読み込み
data_path = '/Users/hayakawakazue/Downloads/second_apt_2024_summer/test/test_01/test.csv'
test_data = pd.read_csv(data_path, low_memory=False)

# 多摩地域の市区町村リスト
tama_cities = [
    '八王子市', '立川市', '武蔵野市', '三鷹市', '青梅市', '府中市', '昭島市', '調布市', '町田市', 
    '小金井市', '小平市', '日野市', '東村山市', '国分寺市', '国立市', '福生市', '狛江市', 
    '東大和市', '清瀬市', '東久留米市', '武蔵村山市', '多摩市', '稲城市', '羽村市', 'あきる野市', 
    '西東京市'
]

# 多摩地域のデータを抽出
tama_data = test_data[test_data['市区町村名'].isin(tama_cities)]

# 抽出したデータを保存
output_path_tama = '/Users/hayakawakazue/Downloads/second_apt_2024_summer/test/test_11_12_14_23/test_tama.csv'
tama_data.to_csv(output_path_tama, index=False)
print(f"多摩地域のデータを保存しました: {output_path_tama}")
# Out:
# 多摩地域のデータを保存しました: /Users/hayakawakazue/Downloads/second_apt_2024_summer/test/test_11_12_14_23/test_tama.csv

# %% [markdown]
# ## test_11_12_14_23.csvとtest_tama.csvを統合する

# %%
import pandas as pd

# 各データセットのパス
data_path_1 = '/Users/hayakawakazue/Downloads/second_apt_2024_summer/test/test_11_12_14_23/test_11_12_14_23.csv'
data_path_2 = '/Users/hayakawakazue/Downloads/second_apt_2024_summer/test/test_11_12_14_23/test_tama.csv'

# 各データセットの読み込み
data_1 = pd.read_csv(data_path_1, low_memory=False)
data_2 = pd.read_csv(data_path_2, low_memory=False)

# データセットの統合
combined_data = pd.concat([data_1, data_2], ignore_index=True)

# 統合データセットの保存
output_path_combined = '/Users/hayakawakazue/Downloads/second_apt_2024_summer/test/test_11_12_14_23/test_11_12_13_14_23.csv'
combined_data.to_csv(output_path_combined, index=False)
print(f"統合されたデータセットを保存しました: {output_path_combined}")
# Out:
# 統合されたデータセットを保存しました: /Users/hayakawakazue/Downloads/second_apt_2024_summer/test/test_11_12_14_23/test_11_12_13_14_23.csv

# %% [markdown]
# ## 2.欠損値の数と割合を確認する

# %%
import pandas as pd

# データファイルを読み込み
data_path = '/Users/hayakawakazue/Downloads/second_apt_2024_summer/test/test_13_27/test_13_27.csv'
test_data = pd.read_csv(data_path)

# 欠損値の数と割合を確認するコード
missing_values_count = test_data.isnull().sum()
missing_values_percentage = (missing_values_count / len(test_data)) * 100

missing_values_summary = pd.DataFrame({
    '欠損値の数': missing_values_count,
    '欠損値の割合 (%)': missing_values_percentage
})

# 欠損値がある列のみ表示
missing_values_summary = missing_values_summary[missing_values_summary['欠損値の数'] > 0]
missing_values_summary.sort_values(by='欠損値の数', ascending=False, inplace=True)

print(missing_values_summary)
# Out:
#             欠損値の数  欠損値の割合 (%)
# 地域          23158  100.000000
# 間口          23158  100.000000
# 土地の形状       23158  100.000000
# 前面道路：種類     23158  100.000000
# 前面道路：幅員（ｍ）  23158  100.000000
# 延床面積（㎡）     23158  100.000000
# 前面道路：方位     23158  100.000000
# 取引の事情等      23087   99.693410
# 改装          16161   69.785819
# 用途          15921   68.749460
# 今後の利用目的     14773   63.792210
# 建ぺい率（％）     14479   62.522670
# 容積率（％）      14479   62.522670
# 都市計画         2130    9.197685
# 最寄駅：距離（分）     761    3.286121
# 間取り           718    3.100440
# 建物の構造         705    3.044304
# 建築年           474    2.046809
# 最寄駅：名称        359    1.550220

# %% [markdown]
# ## 3. 特徴量を指定して削除する

# %%
import pandas as pd
import os

# 北海道のデータファイルを読み込み
data_path = '/Users/hayakawakazue/Downloads/second_apt_2024_summer/test/test_13_27/test_13_27.csv'
test_data = pd.read_csv(data_path)

# 特徴量を指定して削除
columns_to_drop = [
    '地域', '間口', '土地の形状', '前面道路：種類', '種類', '都道府県名', '最寄駅：名称',
    '前面道路：幅員（ｍ）', '延床面積（㎡）', '前面道路：方位', '市区町村名',
    '取引の事情等', '今後の利用目的', '用途', '改装', '価格情報区分', '地区名' 
]
test_data_cleaned = test_data.drop(columns=columns_to_drop)

# 残りの欠損値を確認
remaining_missing_values = test_data_cleaned.isnull().sum()
remaining_missing_values = remaining_missing_values[remaining_missing_values > 0]
remaining_missing_values.sort_values(ascending=False)

# 行数を表示
num_rows = len(test_data_cleaned)
print(f"データの行数: {num_rows}")

print(remaining_missing_values)

# ディレクトリが存在するか確認し、存在しない場合は作成
save_dir = '/Users/hayakawakazue/Downloads/second_apt_2024_summer/test_13_27'
if not os.path.exists(save_dir):
    os.makedirs(save_dir)

# 新しい特徴量を作成してデータを保存
test_data_cleaned_path = os.path.join(save_dir, 'test_13_27.csv_drop_col.csv')
test_data_cleaned.to_csv(test_data_cleaned_path, index=False)

print(f"データを保存しました: {test_data_cleaned_path}")
# Out:
# データの行数: 23158
# 最寄駅：距離（分）      761
# 間取り            718
# 建築年            474
# 建物の構造          705
# 都市計画          2130
# 建ぺい率（％）      14479
# 容積率（％）       14479
# dtype: int64
# データを保存しました: /Users/hayakawakazue/Downloads/second_apt_2024_summer/test_13_27/test_13_27.csv_drop_col.csv

# %% [markdown]
# ## headの確認

# %%
import pandas as pd

# データファイルを読み込み
data_path = '/Users/hayakawakazue/Downloads/second_apt_2024_summer/test/test_13_27/test_13_27.csv'
test_data = pd.read_csv(data_path)

test_data.head()
# Out:
#          ID        種類  価格情報区分  地域  市区町村コード 都道府県名 市区町村名  地区名  最寄駅：名称 最寄駅：距離（分）  \
# 0  13000559  中古マンション等  成約価格情報 NaN    13101   東京都  千代田区  岩本町     岩本町         4
# 1  13000560  中古マンション等  成約価格情報 NaN    13101   東京都  千代田区  岩本町     岩本町         3
# 2  13000561  中古マンション等  成約価格情報 NaN    13101   東京都  千代田区  岩本町     岩本町         4
# 3  13000562  中古マンション等  成約価格情報 NaN    13101   東京都  千代田区  岩本町     秋葉原         5
# 4  13000563  中古マンション等  成約価格情報 NaN    13101   東京都  千代田区  岩本町  神田(東京)         8
#
#    ... 今後の利用目的  前面道路：方位  前面道路：種類  前面道路：幅員（ｍ）  都市計画 建ぺい率（％） 容積率（％）        取引時点  \
# 0  ...     NaN      NaN      NaN         NaN    商業     NaN    NaN  2023年第3四半期
# 1  ...     NaN      NaN      NaN         NaN    商業     NaN    NaN  2023年第3四半期
# 2  ...     NaN      NaN      NaN         NaN    商業     NaN    NaN  2023年第3四半期
# 3  ...     NaN      NaN      NaN         NaN    商業     NaN    NaN  2023年第3四半期
# 4  ...     NaN      NaN      NaN         NaN    商業     NaN    NaN  2023年第3四半期
#
#     改装  取引の事情等
# ...

# %% [markdown]
# ## カテゴリ変数は最頻値、数値変数は最頻値と中央値で補完する

# %%
import pandas as pd
import os

# データファイルを読み込み
data_path = '/Users/hayakawakazue/Downloads/second_apt_2024_summer/test/test_13_27/test_13_27.csv'
test_data = pd.read_csv(data_path)

# カテゴリ変数と数値変数を識別
categorical_cols = test_data.select_dtypes(include=['object']).columns
numerical_cols = test_data.select_dtypes(include=['float64', 'int64']).columns

# カテゴリ変数の欠損値を最頻値で補完
for col in categorical_cols:
    mode_value = test_data[col].mode()[0]
    test_data[col] = test_data[col].fillna(mode_value)

# 建ぺい率と容積率の欠損値を最頻値で補完
test_data['建ぺい率（％）'] = test_data['建ぺい率（％）'].fillna(test_data['建ぺい率（％）'].mode()[0])
test_data['容積率（％）'] = test_data['容積率（％）'].fillna(test_data['容積率（％）'].mode()[0])

# 他の数値変数の欠損値を中央値で補完
for col in numerical_cols:
    if col not in ['建ぺい率（％）', '容積率（％）']:
        median_value = test_data[col].median()
        test_data[col] = test_data[col].fillna(median_value)

# 補完後のデータを確認
missing_values_after = test_data.isnull().sum()
print(missing_values_after)

# 行数を表示
num_rows_after_filling = len(test_data)
print(f"欠損値の補完後のデータの行数: {num_rows_after_filling}")

# ディレクトリが存在するか確認し、存在しない場合は作成
save_dir = '/Users/hayakawakazue/Downloads/second_apt_2024_summer/test/test_13_27'
if not os.path.exists(save_dir):
    os.makedirs(save_dir)

# 新しい特徴量を作成してデータを保存
output_path = os.path.join(save_dir, 'test_13_27_cleaned.csv')
test_data.to_csv(output_path, index=False)

print(f"データを保存しました: {output_path}")
# Out:
# ID                0
# 種類                0
# 価格情報区分            0
# 地域            23158
# 市区町村コード           0
# 都道府県名             0
# 市区町村名             0
# 地区名               0
# 最寄駅：名称            0
# 最寄駅：距離（分）         0
# 間取り               0
# 面積（㎡）             0
# 土地の形状         23158
# 間口            23158
# 延床面積（㎡）       23158
# 建築年               0
# 建物の構造             0
# 用途                0
# 今後の利用目的           0
# 前面道路：方位       23158
# 前面道路：種類       23158
# 前面道路：幅員（ｍ）    23158
# 都市計画              0
# 建ぺい率（％）           0
# 容積率（％）            0
# 取引時点              0
# 改装                0
# 取引の事情等            0
# dtype: int64
# 欠損値の補完後のデータの行数: 23158
# データを保存しました: /Users/hayakawakazue/Downloads/second_apt_2024_summer/test/test_13_27/test_13_27_cleaned.csv

# %% [markdown]
# ## 各特徴量のユニークな値を確認する

# %%
import pandas as pd

# データファイルを読み込み
data_path = '/Users/hayakawakazue/Downloads/second_apt_2024_summer/test/test_13_27/test_13_27_cleaned.csv'
test_data = pd.read_csv(data_path)

# 各特徴量のユニークな値を確認
unique_values_summary = {col: test_data[col].unique() for col in test_data.columns}

# 各特徴量のユニークな値の数を表示
for col, unique_vals in unique_values_summary.items():
    print(f"特徴量 '{col}' のユニークな値の数: {len(unique_vals)}")
    print(f"ユニークな値: {unique_vals[:10]}")  # 最初の10個のユニークな値のみ表示
    print("\n")

# すべてのユニークな値を表示する場合は以下のコメントアウトを外してください
# import ace_tools as tools; tools.display_dataframe_to_user(name="Unique Values Summary", dataframe=pd.DataFrame(unique_values_summary))
# Out:
# 特徴量 'ID' のユニークな値の数: 23158
# ユニークな値: [13000559 13000560 13000561 13000562 13000563 13000564 13000565 13000566
#  13000567 13000568]
#
#
# 特徴量 '種類' のユニークな値の数: 1
# ユニークな値: ['中古マンション等']
#
#
# 特徴量 '価格情報区分' のユニークな値の数: 2
# ユニークな値: ['成約価格情報' '不動産取引価格情報']
#
#
# 特徴量 '地域' のユニークな値の数: 1
# ユニークな値: [nan]
#
#
# 特徴量 '市区町村コード' のユニークな値の数: 115
# ユニークな値: [13101 13102 13103 13104 13105 13106 13107 13108 13109 13110]
#
#
# 特徴量 '都道府県名' のユニークな値の数: 2
# ユニークな値: ['東京都' '大阪府']
#
#
# 特徴量 '市区町村名' のユニークな値の数: 115
# ユニークな値: ['千代田区' '中央区' '港区' '新宿区' '文京区' '台東区' '墨田区' '江東区' '品川区' '目黒区']
#
#
# 特徴量 '地区名' のユニークな値の数: 2213
# ユニークな値: ['岩本町' '隼町' '富士見' '四番町' '九段北' '平河町' '神田佐久間町' '神田神保町' '神田多町' '神田美土代町']
#
#
# 特徴量 '最寄駅：名称' のユニークな値の数: 958
# ユニークな値: ['岩本町' '秋葉原' '神田(東京)' '小伝馬町' '半蔵門' '飯田橋' '麹町' '市ケ谷' '勝どき' '神保町']
#
#
# 特徴量 '最寄駅：距離（分）' のユニークな値の数: 33
# ユニークな値: ['4' '3' '5' '8' '2' '6' '1' '7' '9' '10']
#
#
# 特徴量 '間取り' のユニークな値の数: 31
# ユニークな値: ['１ＬＤＫ' '１Ｒ' '１ＤＫ' '２ＬＤＫ' '１Ｋ＋Ｓ' '１Ｋ' '３ＬＤＫ' '２ＬＤＫ＋Ｓ' '３ＬＤＫ＋Ｓ' '１ＬＤＫ＋Ｓ']
#
#
# ...

# %% [markdown]
# ## 各特徴量のユニークな値を確認する

# %%
import pandas as pd

# データファイルを読み込み
data_path = '/Users/hayakawakazue/Downloads/second_apt_2024_summer/test/test_13_27/test_13_27_cleaned.csv'
test_data = pd.read_csv(data_path)

# ユニークな値を取得
unique_codes = test_data['面積（㎡）'].unique()

# ユニークな値を表示
print(f"面積（㎡）のユニークな値の数: {len(unique_codes)}")
print(f"ユニークな値: {unique_codes}")

# データセットに含まれる行の数を確認
num_rows = test_data.shape[0]
print(f"データセットに含まれる行の数: {num_rows}")
# Out:
# 面積（㎡）のユニークな値の数: 46
# ユニークな値: [  35   40   25   50   60   30   90   65   45  105   75   95   55  100
#    20   80   70   15  120  125   85  170  110  320  115  135  130  180
#   155  145  160  150  200   10  140  670  215  205  210  195  175  165
#   190  290 1400  530]
# データセットに含まれる行の数: 23158

# %% [markdown]
# ## 最寄駅：距離（分）の置き換え

# %%
import pandas as pd
import os

# データファイルを読み込み
data_path = '/Users/hayakawakazue/Downloads/second_apt_2024_summer/test/test_13_27/test_13_27_cleaned.csv'
test_data = pd.read_csv(data_path)

# 置き換えルールを辞書として定義
replace_dict = {
    '30分～60分': 45,
    '1H～1H30': 75,
    '2H～': 120,
    '1H30～2H': 105
}

# 置き換えを実行
test_data['最寄駅：距離（分）'] = test_data['最寄駅：距離（分）'].replace(replace_dict)

# 最寄駅：距離（分）列を数値に変換
test_data['最寄駅：距離（分）'] = pd.to_numeric(test_data['最寄駅：距離（分）'], errors='coerce')

# ディレクトリが存在するか確認し、存在しない場合は作成
save_dir = '/Users/hayakawakazue/Downloads/second_apt_2024_summer/test/test_13_27'
if not os.path.exists(save_dir):
    os.makedirs(save_dir)

# データを保存
output_path = os.path.join(save_dir, 'test_13_27_cleaned_station.csv')
test_data.to_csv(output_path, index=False)

print(f"データを保存しました: {output_path}")

# ユニークな値を表示
unique_values = test_data['最寄駅：距離（分）'].unique()
print(f"ユニークな値: {unique_values}")

# データセットに含まれる行の数を確認
num_rows = test_data.shape[0]
print(f"データセットに含まれる行の数: {num_rows}")
# Out:
# データを保存しました: /Users/hayakawakazue/Downloads/second_apt_2024_summer/test/test_13_27/test_13_27_cleaned_station.csv
# ユニークな値: [  4   3   5   8   2   6   1   7   9  10   0  11  12  13  20  16  14  17
#   75  15  28  18  23  19  21 105  45  24  22  26  27  25  29]
# データセットに含まれる行の数: 23158

# %% [markdown]
# ## 建築年の置き換え
# 日本で一番最初にマンションが分譲されたのは1953年です。それより古いデータは1952年にします。

# %%
import pandas as pd
import os

# データファイルを読み込み
data_path = '/Users/hayakawakazue/Downloads/second_apt_2024_summer/test/test_13_27/test_13_27_cleaned_station.csv'
test_data = pd.read_csv(data_path)

# '建築年'列から「年」を削除し、数値に変換
test_data['建築年'] = test_data['建築年'].str.replace('年', '')

# 「戦前」を1952年とする
test_data['建築年'] = test_data['建築年'].replace('戦前', '1952')

# '建築年'を数値に変換
test_data['建築年'] = pd.to_numeric(test_data['建築年'], errors='coerce')

# 1953年より古いデータにフラグを付ける
test_data['1953年以前'] = test_data['建築年'] < 1953

# 古いデータを何らかの方法で処理する（例：新しい列を作成してフラグを追加）
# 例えば、1953年より古い建物には特定の処理を施す場合
# test_data.loc[test_data['1953年以前'], '建築年'] = 1953  # 1953年未満を1953年に設定する場合

# ディレクトリが存在するか確認し、存在しない場合は作成
save_dir = '/Users/hayakawakazue/Downloads/second_apt_2024_summer/test/test_13_27'
if not os.path.exists(save_dir):
    os.makedirs(save_dir)

# データを保存
output_path = os.path.join(save_dir, 'test_13_27_cleaned_build_year.csv')
test_data.to_csv(output_path, index=False)

print(f"データを保存しました: {output_path}")

# '建築年'のユニークな値を表示
unique_build_years = test_data['建築年'].unique()
print(f"'建築年'のユニークな値: {unique_build_years}")

# データセットに含まれる行の数を確認
num_rows = test_data.shape[0]
print(f"データセットに含まれる行の数: {num_rows}")
# Out:
# データを保存しました: /Users/hayakawakazue/Downloads/second_apt_2024_summer/test/test_13_27/test_13_27_cleaned_build_year.csv
# '建築年'のユニークな値: [2016 2020 2013 2000 1978 1983 2009 2005 2008 2019 1979 1999 2022 2014
#  1981 2015 2004 2003 2011 2012 2017 1970 1972 2001 1998 2021 2007 1982
#  2002 2023 1971 1977 2018 2006 1997 1984 1980 1975 1988 1985 2024 1974
#  2010 1973 1976 1989 1996 1991 1995 1986 1993 1969 1968 1965 1990 1964
#  1992 1994 1967 1987 1962 1963 1956 1966 1961 1959 1952]
# データセットに含まれる行の数: 23158

# %% [markdown]
# ## 取引時点を西暦に変換する

# %%
import pandas as pd
import os
import re

# データファイルを読み込み
data_path = '/Users/hayakawakazue/Downloads/second_apt_2024_summer/test/test_13_27/test_13_27_cleaned_build_year.csv'
test_data = pd.read_csv(data_path)

# 取引時点を西暦に変換する関数
def convert_quarter_to_date(quarter_str):
    match = re.match(r'(\d{4})年第(\d)四半期', quarter_str)
    if match:
        year = int(match.group(1))
        quarter = int(match.group(2))
        if quarter == 1:
            return int(f"{year}03")
        elif quarter == 2:
            return int(f"{year}06")
        elif quarter == 3:
            return int(f"{year}09")
        elif quarter == 4:
            return int(f"{year}12")
    return None

# 取引時点を西暦に変換
test_data['取引時点'] = test_data['取引時点'].apply(convert_quarter_to_date)

# ディレクトリが存在するか確認し、存在しない場合は作成
save_dir = '/Users/hayakawakazue/Downloads/second_apt_2024_summer/test/test_13_27'
if not os.path.exists(save_dir):
    os.makedirs(save_dir)

# データを保存
output_path = os.path.join(save_dir, 'test_13_27_cleaned_transaction_date.csv')
test_data.to_csv(output_path, index=False)

print(f"データを保存しました: {output_path}")

# '取引時点'のユニークな値を表示
unique_transaction_dates = test_data['取引時点'].unique()
print(f"'取引時点'のユニークな値: {unique_transaction_dates}")
# Out:
# データを保存しました: /Users/hayakawakazue/Downloads/second_apt_2024_summer/test/test_13_27/test_13_27_cleaned_transaction_date.csv
# '取引時点'のユニークな値: [202309 202312]

# %% [markdown]
# ## head

# %%
import pandas as pd

# データファイルを読み込み
data_path = '/Users/hayakawakazue/Downloads/second_apt_2024_summer/test/test_13_27/test_13_27_cleaned_transaction_date.csv'
test_data = pd.read_csv(data_path)

print(test_data.head())

# データセットに含まれる行の数を確認
num_rows = test_data.shape[0]
print(f"データセットに含まれる行の数: {num_rows}")
# Out:
#          ID        種類  価格情報区分  地域  市区町村コード 都道府県名 市区町村名  地区名  最寄駅：名称  \
# 0  13000559  中古マンション等  成約価格情報 NaN    13101   東京都  千代田区  岩本町     岩本町
# 1  13000560  中古マンション等  成約価格情報 NaN    13101   東京都  千代田区  岩本町     岩本町
# 2  13000561  中古マンション等  成約価格情報 NaN    13101   東京都  千代田区  岩本町     岩本町
# 3  13000562  中古マンション等  成約価格情報 NaN    13101   東京都  千代田区  岩本町     秋葉原
# 4  13000563  中古マンション等  成約価格情報 NaN    13101   東京都  千代田区  岩本町  神田(東京)
#
#    最寄駅：距離（分）  ... 前面道路：方位  前面道路：種類  前面道路：幅員（ｍ）  都市計画  建ぺい率（％）  容積率（％）    取引時点  \
# 0          4  ...     NaN      NaN         NaN    商業     80.0   200.0  202309
# 1          3  ...     NaN      NaN         NaN    商業     80.0   200.0  202309
# 2          4  ...     NaN      NaN         NaN    商業     80.0   200.0  202309
# 3          5  ...     NaN      NaN         NaN    商業     80.0   200.0  202309
# 4          8  ...     NaN      NaN         NaN    商業     80.0   200.0  202309
#
#     改装  取引の事情等  1953年以前
# 0  未改装  調停・競売等    False
# 1  未改装  調停・競売等    False
# ...

# %% [markdown]
# ## 欠損値の確認

# %%
import pandas as pd

# データファイルを読み込み
data_path = '/Users/hayakawakazue/Downloads/second_apt_2024_summer/test/test_13_27/test_13_27_cleaned_transaction_date.csv'
test_data = pd.read_csv(data_path)

# 欠損値の確認
missing_values = test_data.isnull().sum()
missing_values[missing_values > 0].sort_values(ascending=False)
# Out:
# 地域            23158
# 土地の形状         23158
# 間口            23158
# 延床面積（㎡）       23158
# 前面道路：方位       23158
# 前面道路：種類       23158
# 前面道路：幅員（ｍ）    23158
# dtype: int64

# %% [markdown]
# ## 最寄駅：距離（分）の外れ値の確認と処理

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 日本語フォントの設定
plt.rcParams['font.sans-serif'] = ['Hiragino Maru Gothic Pro']  # Mac用
plt.rcParams['axes.unicode_minus'] = False

# データセットのロード
data_path = '/Users/hayakawakazue/Downloads/second_apt_2024_summer/test/test_13_27/test_13_27_cleaned_transaction_date.csv'
df = pd.read_csv(data_path)

# クリッピングの関数
def clip_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    # 統計情報の表示
    print(f'=== {column}の統計情報（クリッピング前） ===')
    print(df[column].describe())
    
    # クリッピングを実行
    df_clipped = df.copy()
    df_clipped[column] = df[column].clip(lower=lower_bound, upper=upper_bound)
    
    # 統計情報の表示（クリッピング後）
    print(f'=== {column}の統計情報（クリッピング後） ===')
    print(df_clipped[column].describe())
    
    return df_clipped

# 最寄駅：距離（分）のクリッピングを実行
df_clipped = clip_outliers(df, '最寄駅：距離（分）')

# クリッピング前のヒストグラム
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.histplot(df['最寄駅：距離（分）'], bins=30, kde=True)
plt.title('最寄駅：距離（分）のヒストグラム（クリッピング前）')
plt.xlabel('最寄駅：距離（分）')
plt.ylabel('頻度')

# クリッピング後のヒストグラム
plt.subplot(1, 2, 2)
sns.histplot(df_clipped['最寄駅：距離（分）'], bins=30, kde=True)
plt.title('最寄駅：距離（分）のヒストグラム（クリッピング後）')
plt.xlabel('最寄駅：距離（分）')
plt.ylabel('頻度')

plt.tight_layout()
plt.show()

# クリッピング後のデータを保存
output_path_clipped = '/Users/hayakawakazue/Downloads/second_apt_2024_summer/test/test_13_27/test_13_27_clipped_outliers_station.csv'
df_clipped.to_csv(output_path_clipped, index=False)
print(f"クリッピング後のデータを保存しました: {output_path_clipped}")
# Out:
# === 最寄駅：距離（分）の統計情報（クリッピング前） ===
# count    23158.000000
# mean         7.185897
# std          5.129235
# min          0.000000
# 25%          4.000000
# 50%          6.000000
# 75%          9.000000
# max        105.000000
# Name: 最寄駅：距離（分）, dtype: float64
# === 最寄駅：距離（分）の統計情報（クリッピング後） ===
# count    23158.000000
# mean         6.931622
# std          4.038114
# min          0.000000
# 25%          4.000000
# 50%          6.000000
# 75%          9.000000
# max         16.500000
# Name: 最寄駅：距離（分）, dtype: float64
# クリッピング後のデータを保存しました: /Users/hayakawakazue/Downloads/second_apt_2024_summer/test/test_13_27/test_13_27_clipped_outliers_station.csv

# %% [markdown]
# ## 面積（㎡）の外れ値の確認と処理

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# データセットのロード
data_path = '/Users/hayakawakazue/Downloads/second_apt_2024_summer/test/test_13_27/test_13_27_clipped_outliers_station.csv'
df = pd.read_csv(data_path)

# クリッピングの関数
def clip_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    # 統計情報の表示
    print(f'=== {column}の統計情報（クリッピング前） ===')
    print(df[column].describe())
    
    # クリッピングを実行
    df_clipped = df.copy()
    df_clipped[column] = df[column].clip(lower=lower_bound, upper=upper_bound)
    
    # 統計情報の表示（クリッピング後）
    print(f'=== {column}の統計情報（クリッピング後） ===')
    print(df_clipped[column].describe())
    
    return df_clipped

# 面積（㎡）のクリッピングを実行
df_clipped = clip_outliers(df, '面積（㎡）')

# クリッピング前のヒストグラム
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.histplot(df['面積（㎡）'], bins=30, kde=True)
plt.title('面積（㎡）のヒストグラム（クリッピング前）')
plt.xlabel('面積（㎡）')
plt.ylabel('頻度')

# クリッピング後のヒストグラム
plt.subplot(1, 2, 2)
sns.histplot(df_clipped['面積（㎡）'], bins=30, kde=True)
plt.title('面積（㎡）のヒストグラム（クリッピング後）')
plt.xlabel('面積（㎡）')
plt.ylabel('頻度')

plt.tight_layout()
plt.show()

# クリッピング後のデータの一部を表示して確認
print(df_clipped.head())

# クリッピング後のデータを保存
output_path_clipped = '/Users/hayakawakazue/Downloads/second_apt_2024_summer/test/test_13_27/test_13_27_clipped_outliers_space.csv'
df_clipped.to_csv(output_path_clipped, index=False)
print(f"クリッピング後のデータを保存しました: {output_path_clipped}")
# Out:
# === 面積（㎡）の統計情報（クリッピング前） ===
# count    23158.000000
# mean        57.623284
# std         25.835050
# min         10.000000
# 25%         40.000000
# 50%         60.000000
# 75%         75.000000
# max       1400.000000
# Name: 面積（㎡）, dtype: float64
# === 面積（㎡）の統計情報（クリッピング後） ===
# count    23158.000000
# mean        57.404029
# std         23.200879
# min         10.000000
# 25%         40.000000
# 50%         60.000000
# 75%         75.000000
# max        127.500000
# Name: 面積（㎡）, dtype: float64
#          ID        種類  価格情報区分  地域  市区町村コード 都道府県名 市区町村名  地区名  最寄駅：名称  \
# 0  13000559  中古マンション等  成約価格情報 NaN    13101   東京都  千代田区  岩本町     岩本町
# 1  13000560  中古マンション等  成約価格情報 NaN    13101   東京都  千代田区  岩本町     岩本町
# 2  13000561  中古マンション等  成約価格情報 NaN    13101   東京都  千代田区  岩本町     岩本町
# 3  13000562  中古マンション等  成約価格情報 NaN    13101   東京都  千代田区  岩本町     秋葉原
# 4  13000563  中古マンション等  成約価格情報 NaN    13101   東京都  千代田区  岩本町  神田(東京)
#
# ...

# %% [markdown]
# ## 建築年の外れ値の確認と処理

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# データセットのロード
data_path = '/Users/hayakawakazue/Downloads/second_apt_2024_summer/test/test_13_27/test_13_27_clipped_outliers_space.csv'
df = pd.read_csv(data_path)

# クリッピングの関数
def clip_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    # 統計情報の表示
    print(f'=== {column}の統計情報（クリッピング前） ===')
    print(df[column].describe())
    
    # クリッピングを実行
    df_clipped = df.copy()
    df_clipped[column] = df[column].clip(lower=lower_bound, upper=upper_bound)
    # 統計情報の表示（クリッピング後）
    print(f'=== {column}の統計情報（クリッピング後） ===')
    print(df_clipped[column].describe())
    
    return df_clipped

# 建築年のクリッピングを実行
df_clipped = clip_outliers(df, '建築年')

# クリッピング前のヒストグラム
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.histplot(df['建築年'], bins=30, kde=True)
plt.title('建築年のヒストグラム（クリッピング前）')
plt.xlabel('建築年')
plt.ylabel('頻度')

# クリッピング後のヒストグラム
plt.subplot(1, 2, 2)
sns.histplot(df_clipped['建築年'], bins=30, kde=True)
plt.title('建築年のヒストグラム（クリッピング後）')
plt.xlabel('建築年')
plt.ylabel('頻度')

plt.tight_layout()
plt.show()

# クリッピング後のデータを保存
output_path_clipped = '/Users/hayakawakazue/Downloads/second_apt_2024_summer/test/test_13_27/test_13_27_clipped_outliers_yearbuilt.csv'
df_clipped.to_csv(output_path_clipped, index=False)
print(f"クリッピング後のデータを保存しました: {output_path_clipped}")
# Out:
# === 建築年の統計情報（クリッピング前） ===
# count    23158.000000
# mean      2000.141938
# std         14.742154
# min       1952.000000
# 25%       1988.000000
# 50%       2003.000000
# 75%       2013.000000
# max       2024.000000
# Name: 建築年, dtype: float64
# === 建築年の統計情報（クリッピング後） ===
# count    23158.000000
# mean      2000.141938
# std         14.742154
# min       1952.000000
# 25%       1988.000000
# 50%       2003.000000
# 75%       2013.000000
# max       2024.000000
# Name: 建築年, dtype: float64
# クリッピング後のデータを保存しました: /Users/hayakawakazue/Downloads/second_apt_2024_summer/test/test_13_27/test_13_27_clipped_outliers_yearbuilt.csv

# %% [markdown]
# ## 建ぺい率の外れ値の確認と処理

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# データセットのロード
data_path = '/Users/hayakawakazue/Downloads/second_apt_2024_summer/test/test_13_27/test_13_27_clipped_outliers_yearbuilt.csv'
df = pd.read_csv(data_path)

# クリッピングの関数
def clip_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    # 統計情報の表示
    print(f'=== {column}の統計情報（クリッピング前） ===')
    print(df[column].describe())

    # クリッピングを実行
    df_clipped = df.copy()
    df_clipped[column] = df[column].clip(lower=lower_bound, upper=upper_bound)
    # 統計情報の表示（クリッピング後）
    print(f'=== {column}の統計情報（クリッピング後） ===')
    print(df_clipped[column].describe())
    
    return df_clipped

# 建ぺい率（％）のクリッピングを実行
df_clipped = clip_outliers(df, '建ぺい率（％）')

# クリッピング前のヒストグラム
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.histplot(df['建ぺい率（％）'], bins=30, kde=True)
plt.title('建ぺい率（％）のヒストグラム（クリッピング前）')
plt.xlabel('建ぺい率（％）')
plt.ylabel('頻度')

# クリッピング後のヒストグラム
plt.subplot(1, 2, 2)
sns.histplot(df_clipped['建ぺい率（％）'], bins=30, kde=True)
plt.title('建ぺい率（％）のヒストグラム（クリッピング後）')
plt.xlabel('建ぺい率（％）')
plt.ylabel('頻度')

plt.tight_layout()
plt.show()

# クリッピング後のデータを保存
output_path_clipped = '/Users/hayakawakazue/Downloads/second_apt_2024_summer/test/test_13_27/test_13_27_clipped_outliers_bcr.csv'
df_clipped.to_csv(output_path_clipped, index=False)
print(f"クリッピング後のデータを保存しました: {output_path_clipped}")
# Out:
# === 建ぺい率（％）の統計情報（クリッピング前） ===
# count    23158.000000
# mean        76.429744
# std          7.822499
# min         40.000000
# 25%         80.000000
# 50%         80.000000
# 75%         80.000000
# max         80.000000
# Name: 建ぺい率（％）, dtype: float64
# === 建ぺい率（％）の統計情報（クリッピング後） ===
# count    23158.0
# mean        80.0
# std          0.0
# min         80.0
# 25%         80.0
# 50%         80.0
# 75%         80.0
# max         80.0
# Name: 建ぺい率（％）, dtype: float64
# クリッピング後のデータを保存しました: /Users/hayakawakazue/Downloads/second_apt_2024_summer/test/test_13_27/test_13_27_clipped_outliers_bcr.csv

# %% [markdown]
# ## 容積率の外れ値の確認と処理

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# データセットのロード
data_path = '/Users/hayakawakazue/Downloads/second_apt_2024_summer/test/test_13_27/test_13_27_clipped_outliers_bcr.csv'
df = pd.read_csv(data_path)

# クリッピングの関数
def clip_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    # 統計情報の表示
    print(f'=== {column}の統計情報（クリッピング前） ===')
    print(df[column].describe())

    # クリッピングを実行
    df_clipped = df.copy()
    df_clipped[column] = df[column].clip(lower=lower_bound, upper=upper_bound)
    # 統計情報の表示（クリッピング後）
    print(f'=== {column}の統計情報（クリッピング後） ===')
    print(df_clipped[column].describe())
    
    return df_clipped

# 容積率（％）のクリッピングを実行
df_clipped = clip_outliers(df, '容積率（％）')

# クリッピング前のヒストグラム
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.histplot(df['容積率（％）'], bins=30, kde=True)
plt.title('容積率（％）のヒストグラム（クリッピング前）')
plt.xlabel('容積率（％）')
plt.ylabel('頻度')

# クリッピング後のヒストグラム
plt.subplot(1, 2, 2)
sns.histplot(df_clipped['容積率（％）'], bins=30, kde=True)
plt.title('容積率（％）のヒストグラム（クリッピング後）')
plt.xlabel('容積率（％）')
plt.ylabel('頻度')

plt.tight_layout()
plt.show()

# クリッピング後のデータを保存
output_path_clipped = '/Users/hayakawakazue/Downloads/second_apt_2024_summer/test/test_13_27/test_13_27_clipped_outliers_far.csv'
df_clipped.to_csv(output_path_clipped, index=False)
print(f"クリッピング後のデータを保存しました: {output_path_clipped}")
# Out:
# === 容積率（％）の統計情報（クリッピング前） ===
# count    23158.000000
# mean       260.088522
# std        126.683834
# min         80.000000
# 25%        200.000000
# 50%        200.000000
# 75%        300.000000
# max       1000.000000
# Name: 容積率（％）, dtype: float64
# === 容積率（％）の統計情報（クリッピング後） ===
# count    23158.000000
# mean       246.253131
# std         87.534047
# min         80.000000
# 25%        200.000000
# 50%        200.000000
# 75%        300.000000
# max        450.000000
# Name: 容積率（％）, dtype: float64
# クリッピング後のデータを保存しました: /Users/hayakawakazue/Downloads/second_apt_2024_summer/test/test_13_27/test_13_27_clipped_outliers_far.csv

# %% [markdown]
# ## 取引時点の外れ値の確認と処理

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# データセットのロード
data_path = '/Users/hayakawakazue/Downloads/second_apt_2024_summer/test/test_13_27/test_13_27_clipped_outliers_far.csv'
df = pd.read_csv(data_path)

# クリッピングの関数
def clip_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    # 統計情報の表示
    print(f'=== {column}の統計情報（クリッピング前） ===')
    print(df[column].describe())

    # クリッピングを実行
    df_clipped = df.copy()
    df_clipped[column] = df[column].clip(lower=lower_bound, upper=upper_bound)
    
    # 統計情報の表示（クリッピング後）
    print(f'=== {column}の統計情報（クリッピング後） ===')
    print(df_clipped[column].describe())
    
    return df_clipped

# 取引時点のクリッピングを実行
df_clipped = clip_outliers(df, '取引時点')

# クリッピング前のヒストグラム
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.histplot(df['取引時点'], bins=30, kde=True)
plt.title('取引時点のヒストグラム（クリッピング前）')
plt.xlabel('取引時点')
plt.ylabel('頻度')

# クリッピング後のヒストグラム
plt.subplot(1, 2, 2)
sns.histplot(df_clipped['取引時点'], bins=30, kde=True)
plt.title('取引時点のヒストグラム（クリッピング後）')
plt.xlabel('取引時点')
plt.ylabel('頻度')

plt.tight_layout()
plt.show()

# クリッピング後のデータを保存
output_path_clipped = '/Users/hayakawakazue/Downloads/second_apt_2024_summer/test/test_13_27/test_13_27_clipped_outliers_transaction_date.csv'
df_clipped.to_csv(output_path_clipped, index=False)
print(f"クリッピング後のデータを保存しました: {output_path_clipped}")
# Out:
# === 取引時点の統計情報（クリッピング前） ===
# count     23158.000000
# mean     202310.373176
# std           1.494661
# min      202309.000000
# 25%      202309.000000
# 50%      202309.000000
# 75%      202312.000000
# max      202312.000000
# Name: 取引時点, dtype: float64
# === 取引時点の統計情報（クリッピング後） ===
# count     23158.000000
# mean     202310.373176
# std           1.494661
# min      202309.000000
# 25%      202309.000000
# 50%      202309.000000
# 75%      202312.000000
# max      202312.000000
# Name: 取引時点, dtype: float64
# クリッピング後のデータを保存しました: /Users/hayakawakazue/Downloads/second_apt_2024_summer/test/test_13_27/test_13_27_clipped_outliers_transaction_date.csv

# %% [markdown]
# # headを確認する

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# テストデータの読み込み
data_path = '/Users/hayakawakazue/Downloads/second_apt_2024_summer/test/test_13_27/test_13_27_clipped_outliers_transaction_date.csv'

test_data = pd.read_csv(data_path, low_memory=False)

print(test_data.head())

# データセットに含まれる行の数を確認
num_rows = test_data.shape[0]
print(f"データセットに含まれる行の数: {num_rows}")
# Out:
#          ID        種類  価格情報区分  地域  市区町村コード 都道府県名 市区町村名  地区名  最寄駅：名称  \
# 0  13000559  中古マンション等  成約価格情報 NaN    13101   東京都  千代田区  岩本町     岩本町
# 1  13000560  中古マンション等  成約価格情報 NaN    13101   東京都  千代田区  岩本町     岩本町
# 2  13000561  中古マンション等  成約価格情報 NaN    13101   東京都  千代田区  岩本町     岩本町
# 3  13000562  中古マンション等  成約価格情報 NaN    13101   東京都  千代田区  岩本町     秋葉原
# 4  13000563  中古マンション等  成約価格情報 NaN    13101   東京都  千代田区  岩本町  神田(東京)
#
#    最寄駅：距離（分）  ... 前面道路：方位  前面道路：種類  前面道路：幅員（ｍ）  都市計画  建ぺい率（％）  容積率（％）    取引時点  \
# 0        4.0  ...     NaN      NaN         NaN    商業     80.0   200.0  202309
# 1        3.0  ...     NaN      NaN         NaN    商業     80.0   200.0  202309
# 2        4.0  ...     NaN      NaN         NaN    商業     80.0   200.0  202309
# 3        5.0  ...     NaN      NaN         NaN    商業     80.0   200.0  202309
# 4        8.0  ...     NaN      NaN         NaN    商業     80.0   200.0  202309
#
#     改装  取引の事情等  1953年以前
# 0  未改装  調停・競売等    False
# 1  未改装  調停・競売等    False
# ...

# %%
# IDが13506922の行を特定して表示
specific_id = 13506922
specific_row = test_data[test_data['ID'] == specific_id]

# 結果を表示
print("Row with ID 13506922:")
print(specific_row)
# Out:
# Row with ID 13506922:
#              ID        種類     価格情報区分  地域  市区町村コード 都道府県名 市区町村名  地区名 最寄駅：名称  \
# 14440  13506922  中古マンション等  不動産取引価格情報 NaN    13206   東京都   府中市  住吉町    中河原
#
#        最寄駅：距離（分）  ... 前面道路：方位  前面道路：種類  前面道路：幅員（ｍ）  都市計画  建ぺい率（％）  容積率（％）  \
# 14440        3.0  ...     NaN      NaN         NaN  １中住専     80.0   200.0
#
#          取引時点   改装  取引の事情等  1953年以前
# 14440  202309  未改装  調停・競売等     True
#
# [1 rows x 29 columns]
